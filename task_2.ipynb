# %% [markdown]
# # B8IT155 – Big Data Managing and Processing

# %% [markdown]
# ## Task 2: MongoDB (PyMongo)

# %% [markdown]
# ### Setup Environment with PyMongo
# PyMongo is intalled.

# %%
# Install PyMongo.
# !pip install pymongo
# Out:
# Collecting pymongo
#   Downloading pymongo-4.16.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (10.0 kB)
# Collecting dnspython<3.0.0,>=2.6.1 (from pymongo)
#   Downloading dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Downloading pymongo-4.16.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 11.7 MB/s eta 0:00:00
# Downloading dnspython-2.8.0-py3-none-any.whl (331 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 31.1 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.8.0 pymongo-4.16.0

# %% [markdown]
# ### Connect to MongoDB Atlas
# My URI is utilised to connect to the DB, then the connection is verified.

# %%
# Import relevant libraries for the connection and using secrets.
from google.colab import userdata
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

# The URI is loaded from Colab Secrets (the key icon in the left sidebar).
uri = userdata.get('MONGO_URI')

# Create a new client and connect to the Atlas cluster.
client = MongoClient(uri, server_api=ServerApi('1'))

# Ping the deployment to confirm a successful connection.
try:
    client.admin.command('ping')
    print('Pinged your deployment. You successfully connected to MongoDB!')
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %% [markdown]
# ### Create the `members` Database and Insert Data
#
# The data below models each person as a document.
# Favourite sports are stored as a list to allow multiple values per person
# Address is stored as an nested document, as this is how it is represented in the table.

# %%
# Define the member data as a list of Python dictionaries.
# Each dictionary is one MongoDB document.
members_data = [
    {
        'first_name': 'Carol',
        'last_name': 'Smith',
        'age': 50,
        'favourite_sports': ['Tennis', 'Badminton'],
        'address': {'city': 'Dublin', 'street': 'Abbey Rd.', 'number': 1},
    },
    {
        'first_name': 'Richard',
        'last_name': 'Miller',
        'age': 30.5,
        'favourite_sports': ['Tennis'],
        'address': {'city': 'Cork', 'street': 'Temple St.'},
    },
    {
        'first_name': 'Thomas',
        'last_name': 'Garcia',
        'age': 55,
        'favourite_sports': ['Football'],
        'address': {'city': 'Galway', 'street': 'Henry St.', 'number': 3},
    },
    {
        'first_name': 'Eugenia',
        'last_name': 'Jones',
        'age': 22,
        'favourite_sports': ['Handball', 'Basketball'],
        'address': {'city': 'Belfast', 'street': 'Oakley Rd.'},
    },
    {
        'first_name': 'Andrew',
        'last_name': 'Hernandez',
        'age': 18,
        'favourite_sports': ['Basketball'],
        'address': {'city': 'Dublin', 'number': 4},
    },
]

# %%
try: # Create/Select the 'members' database and 'people' collection.
  # If the db is not present, it will be created.
  db = client.members
  people = db.people

  # Insert all people into the database..
  result = people.insert_many(members_data)

except Exception as e:
    print(f"An error occurred: {e}")

# Confirm the people are in the database.
for person in people.find({}):
      print(person)
# Out:
# An error occurred: batch op errors occurred, full error: {'writeErrors': [{'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: members.people index: _id_ dup key: { _id: ObjectId('69c04546d11f9edd776f6857') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('69c04546d11f9edd776f6857')}, 'op': {'first_name': 'Carol', 'last_name': 'Smith', 'age': 50, 'favourite_sports': ['Tennis', 'Badminton'], 'address': {'city': 'Dublin', 'street': 'Abbey Rd.', 'number': 1}, '_id': ObjectId('69c04546d11f9edd776f6857')}}], 'writeConcernErrors': [], 'nInserted': 0, 'nUpserted': 0, 'nMatched': 0, 'nModified': 0, 'nRemoved': 0, 'upserted': []}
# {'_id': ObjectId('69c04546d11f9edd776f6857'), 'first_name': 'Carol', 'last_name': 'Smith', 'age': 50, 'favourite_sports': ['Tennis', 'Badminton'], 'address': {'city': 'Dublin', 'street': 'Abbey Rd.', 'number': 1}}
# {'_id': ObjectId('69c04546d11f9edd776f6858'), 'first_name': 'Richard', 'last_name': 'Miller', 'age': 30.5, 'favourite_sports': ['Tennis'], 'address': {'city': 'Cork', 'street': 'Temple St.'}}
# {'_id': ObjectId('69c04546d11f9edd776f6859'), 'first_name': 'Thomas', 'last_name': 'Garcia', 'age': 55, 'favourite_sports': ['Football'], 'address': {'city': 'Galway', 'street': 'Henry St.', 'number': 3}}
# {'_id': ObjectId('69c04546d11f9edd776f685a'), 'first_name': 'Eugenia', 'last_name': 'Jones', 'age': 22, 'favourite_sports': ['Handball', 'Basketball'], 'address': {'city': 'Belfast', 'street': 'Oakley Rd.'}}
# {'_id': ObjectId('69c04546d11f9edd776f685b'), 'first_name': 'Andrew', 'last_name': 'Hernandez', 'age': 18, 'favourite_sports': ['Basketball'], 'address': {'city': 'Dublin', 'number': 4}}

# %% [markdown]
# ### Q1: Display all information about each person except for their address.

# %%
# find() with an empty query {} returns all documents.
# {"address": 0} excludes the address field from the output.
results_1 = people.find({}, {'address': 0})

for doc in results_1:
    print(doc)
# Out:
# {'_id': ObjectId('69c04546d11f9edd776f6857'), 'first_name': 'Carol', 'last_name': 'Smith', 'age': 50, 'favourite_sports': ['Tennis', 'Badminton']}
# {'_id': ObjectId('69c04546d11f9edd776f6858'), 'first_name': 'Richard', 'last_name': 'Miller', 'age': 30.5, 'favourite_sports': ['Tennis']}
# {'_id': ObjectId('69c04546d11f9edd776f6859'), 'first_name': 'Thomas', 'last_name': 'Garcia', 'age': 55, 'favourite_sports': ['Football']}
# {'_id': ObjectId('69c04546d11f9edd776f685a'), 'first_name': 'Eugenia', 'last_name': 'Jones', 'age': 22, 'favourite_sports': ['Handball', 'Basketball']}
# {'_id': ObjectId('69c04546d11f9edd776f685b'), 'first_name': 'Andrew', 'last_name': 'Hernandez', 'age': 18, 'favourite_sports': ['Basketball']}
